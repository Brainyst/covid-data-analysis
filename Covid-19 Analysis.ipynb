# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
url = "https://raw.githubusercontent.com/SR1608/Datasets/main/covid-data.csv"

# %% [markdown]
# ## Importing the dataset using Pandas from above mentioned url

# %%
df = pd.read_csv(url)

# %%
df.head()
# Out:
#   iso_code continent     location      date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  31/12/19          NaN        0.0
# 1      AFG      Asia  Afghanistan  01/01/20          NaN        0.0
# 2      AFG      Asia  Afghanistan  02/01/20          NaN        0.0
# 3      AFG      Asia  Afghanistan  03/01/20          NaN        0.0
# 4      AFG      Asia  Afghanistan  04/01/20          NaN        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         0.0                  NaN  ...
# 1                 NaN           NaN         0.0                  NaN  ...
# 2                 NaN           NaN         0.0                  NaN  ...
# 3                 NaN           NaN         0.0                  NaN  ...
# 4                 NaN           NaN         0.0                  NaN  ...
#
#    gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# ...

# %%
df.tail()
# Out:
#       iso_code continent       location      date  total_cases  new_cases  \
# 57389      NaN       NaN  International  13/11/20        696.0        NaN
# 57390      NaN       NaN  International  14/11/20        696.0        NaN
# 57391      NaN       NaN  International  15/11/20        696.0        NaN
# 57392      NaN       NaN  International  16/11/20        696.0        NaN
# 57393      NaN       NaN  International  17/11/20        696.0        NaN
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 57389                 NaN           7.0         NaN                  NaN  ...
# 57390                 NaN           7.0         NaN                  NaN  ...
# 57391                 NaN           7.0         NaN                  NaN  ...
# 57392                 NaN           7.0         NaN                  NaN  ...
# 57393                 NaN           7.0         NaN                  NaN  ...
#
# ...

# %% [markdown]
# ## High Level Data Understanding:

# %%
# Find no. of rows & columns in the dataset
df.shape
# Out:
# (57394, 49)

# %%
# Data types of columns
df.dtypes
# Out:
# iso_code                               object
# continent                              object
# location                               object
# date                                   object
# total_cases                           float64
# new_cases                             float64
# new_cases_smoothed                    float64
# total_deaths                          float64
# new_deaths                            float64
# new_deaths_smoothed                   float64
# total_cases_per_million               float64
# new_cases_per_million                 float64
# new_cases_smoothed_per_million        float64
# total_deaths_per_million              float64
# new_deaths_per_million                float64
# new_deaths_smoothed_per_million       float64
# reproduction_rate                     float64
# icu_patients                          float64
# icu_patients_per_million              float64
# hosp_patients                         float64
# ...

# %%
# Info & describe of data in dataframe.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57394 entries, 0 to 57393
# Data columns (total 49 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   iso_code                            57071 non-null  object
#  1   continent                           56748 non-null  object
#  2   location                            57394 non-null  object
#  3   date                                57394 non-null  object
#  4   total_cases                         53758 non-null  float64
#  5   new_cases                           56465 non-null  float64
#  6   new_cases_smoothed                  55652 non-null  float64
#  7   total_deaths                        44368 non-null  float64
#  8   new_deaths                          56465 non-null  float64
#  9   new_deaths_smoothed                 55652 non-null  float64
#  10  total_cases_per_million             53471 non-null  float64
# ...

# %%
df.describe(include="all")
# Out:
#        iso_code continent     location      date   total_cases      new_cases  \
# count     57071     56748        57394     57394  5.375800e+04   56465.000000
# unique      215         6          216       323           NaN            NaN
# top         AFG    Europe  Afghanistan  30/10/20           NaN            NaN
# freq        323     14828          323       215           NaN            NaN
# mean        NaN       NaN          NaN       NaN  1.677974e+05    1953.576941
# std         NaN       NaN          NaN       NaN  1.693038e+06   18269.650340
# min         NaN       NaN          NaN       NaN  1.000000e+00   -8261.000000
# 25%         NaN       NaN          NaN       NaN  1.800000e+02       0.000000
# 50%         NaN       NaN          NaN       NaN  2.070000e+03      14.000000
# 75%         NaN       NaN          NaN       NaN  2.235675e+04     235.000000
# max         NaN       NaN          NaN       NaN  5.515465e+07  646281.000000
#
# ...

# %% [markdown]
# ## Low Level Data Understanding:

# %%
# Find count of unique values in location column.
unique_locations = df["location"].nunique()
print(unique_locations)
# Out:
# 216

# %%
# Find which continent has maximum frequency using values counts.
max_freq_cont = df["continent"].value_counts().idxmax()
print(max_freq_cont)
# Out:
# Europe

# %%
# Find maximum & mean value in 'total_cases'.
max_total_cases = df["total_cases"].max()
mean_total_cases = df["total_cases"].mean()
print("Max Total Cases:",max_total_cases)
print("Mean Total Cases:",mean_total_cases)
# Out:
# Max Total Cases: 55154651.0
# Mean Total Cases: 167797.3688753302

# %%
# Find 25%,50% & 75% quartile value in 'total_deaths'.
df["total_deaths"].quantile([0.25, 0.50, 0.75]).round(2)
# Out:
# 0.25     13.0
# 0.50     84.0
# 0.75    727.0
# Name: total_deaths, dtype: float64

# %%
#  Find which continent has maximum 'human_development_index'.
max_hdi_continent = df.groupby("continent").agg({'human_development_index':'max'})
max_hdi_continent.sort_values(by='human_development_index', ascending=False).head(1)
# Out:
#            human_development_index
# continent
# Europe                       0.953

# %%
# Find which continent has minimum 'gdp_per_capita'.
min_gdp_per_capita = df.groupby("continent").agg({'gdp_per_capita':'min'})
min_gdp_per_capita.head(1)
# Out:
#            gdp_per_capita
# continent
# Africa             661.24

# %% [markdown]
# ## Filter the dataframe with only this columns
# ['continent','location','date','total_cases','total_deaths','gdp_per_c
# pita''
# human_development_index'] and update the data frame.

# %%
df =  df[['continent','location','date','total_cases','total_deaths','gdp_per_capita','human_development_index']]

# %%
df
# Out:
#       continent       location      date  total_cases  total_deaths  \
# 0          Asia    Afghanistan  31/12/19          NaN           NaN
# 1          Asia    Afghanistan  01/01/20          NaN           NaN
# 2          Asia    Afghanistan  02/01/20          NaN           NaN
# 3          Asia    Afghanistan  03/01/20          NaN           NaN
# 4          Asia    Afghanistan  04/01/20          NaN           NaN
# ...         ...            ...       ...          ...           ...
# 57389       NaN  International  13/11/20        696.0           7.0
# 57390       NaN  International  14/11/20        696.0           7.0
# 57391       NaN  International  15/11/20        696.0           7.0
# 57392       NaN  International  16/11/20        696.0           7.0
# 57393       NaN  International  17/11/20        696.0           7.0
#
#        gdp_per_capita  human_development_index
# 0            1803.987                    0.498
# 1            1803.987                    0.498
# ...

# %% [markdown]
# ## Data Cleaning

# %%
# Remove all duplicates observation
df.duplicated().sum()
# Out:
# 0

# %%
df = df.drop_duplicates()

# %%
df
# Out:
#       continent       location      date  total_cases  total_deaths  \
# 0          Asia    Afghanistan  31/12/19          NaN           NaN
# 1          Asia    Afghanistan  01/01/20          NaN           NaN
# 2          Asia    Afghanistan  02/01/20          NaN           NaN
# 3          Asia    Afghanistan  03/01/20          NaN           NaN
# 4          Asia    Afghanistan  04/01/20          NaN           NaN
# ...         ...            ...       ...          ...           ...
# 57389       NaN  International  13/11/20        696.0           7.0
# 57390       NaN  International  14/11/20        696.0           7.0
# 57391       NaN  International  15/11/20        696.0           7.0
# 57392       NaN  International  16/11/20        696.0           7.0
# 57393       NaN  International  17/11/20        696.0           7.0
#
#        gdp_per_capita  human_development_index
# 0            1803.987                    0.498
# 1            1803.987                    0.498
# ...

# %%
# Find missing values in all columns.
df.isnull().sum()
# Out:
# continent                    646
# location                       0
# date                           0
# total_cases                 3636
# total_deaths               13026
# gdp_per_capita              7027
# human_development_index     8147
# dtype: int64

# %%
# Remove all observations where continent column value is missing
df = df.dropna(subset=['continent'])

# %%
df
# Out:
#       continent     location      date  total_cases  total_deaths  \
# 0          Asia  Afghanistan  31/12/19          NaN           NaN
# 1          Asia  Afghanistan  01/01/20          NaN           NaN
# 2          Asia  Afghanistan  02/01/20          NaN           NaN
# 3          Asia  Afghanistan  03/01/20          NaN           NaN
# 4          Asia  Afghanistan  04/01/20          NaN           NaN
# ...         ...          ...       ...          ...           ...
# 56743    Africa     Zimbabwe  13/11/20       8696.0         255.0
# 56744    Africa     Zimbabwe  14/11/20       8765.0         257.0
# 56745    Africa     Zimbabwe  15/11/20       8786.0         257.0
# 56746    Africa     Zimbabwe  16/11/20       8786.0         257.0
# 56747    Africa     Zimbabwe  17/11/20       8897.0         257.0
#
#        gdp_per_capita  human_development_index
# 0            1803.987                    0.498
# 1            1803.987                    0.498
# ...

# %%
# Fill all missing values with 0
df = df.fillna(0)
df
# Out:
#       continent     location      date  total_cases  total_deaths  \
# 0          Asia  Afghanistan  31/12/19          0.0           0.0
# 1          Asia  Afghanistan  01/01/20          0.0           0.0
# 2          Asia  Afghanistan  02/01/20          0.0           0.0
# 3          Asia  Afghanistan  03/01/20          0.0           0.0
# 4          Asia  Afghanistan  04/01/20          0.0           0.0
# ...         ...          ...       ...          ...           ...
# 56743    Africa     Zimbabwe  13/11/20       8696.0         255.0
# 56744    Africa     Zimbabwe  14/11/20       8765.0         257.0
# 56745    Africa     Zimbabwe  15/11/20       8786.0         257.0
# 56746    Africa     Zimbabwe  16/11/20       8786.0         257.0
# 56747    Africa     Zimbabwe  17/11/20       8897.0         257.0
#
#        gdp_per_capita  human_development_index
# 0            1803.987                    0.498
# 1            1803.987                    0.498
# ...

# %%
df.isnull().sum()
# Out:
# continent                  0
# location                   0
# date                       0
# total_cases                0
# total_deaths               0
# gdp_per_capita             0
# human_development_index    0
# dtype: int64

# %% [markdown]
# ## Date time format:

# %%
# Convert date column in datetime format using pandas.to_datetime
df["date"] = pd.to_datetime(df["date"])
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_3676\32482781.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df["date"] = pd.to_datetime(df["date"])

# %%
df.dtypes
# Out:
# continent                          object
# location                           object
# date                       datetime64[ns]
# total_cases                       float64
# total_deaths                      float64
# gdp_per_capita                    float64
# human_development_index           float64
# dtype: object

# %%
# Create new column month after extracting month data from date column
df["month"] = pd.DatetimeIndex(df["date"]).month

# %%
df.head()
# Out:
#   continent     location       date  total_cases  total_deaths  \
# 0      Asia  Afghanistan 2019-12-31          0.0           0.0
# 1      Asia  Afghanistan 2020-01-01          0.0           0.0
# 2      Asia  Afghanistan 2020-02-01          0.0           0.0
# 3      Asia  Afghanistan 2020-03-01          0.0           0.0
# 4      Asia  Afghanistan 2020-04-01          0.0           0.0
#
#    gdp_per_capita  human_development_index  month
# 0        1803.987                    0.498     12
# 1        1803.987                    0.498      1
# 2        1803.987                    0.498      2
# 3        1803.987                    0.498      3
# 4        1803.987                    0.498      4

# %% [markdown]
# ## Data Aggregation:

# %%
# Find max value in all columns using groupby function on 'continent' column
df.groupby("continent").max().reset_index()
# Out:
#        continent                      location       date  total_cases  \
# 0         Africa                      Zimbabwe 2020-12-11     752269.0
# 1           Asia                         Yemen 2020-12-11    8874290.0
# 2         Europe                       Vatican 2020-12-11    1991233.0
# 3  North America  United States Virgin Islands 2020-12-11   11205486.0
# 4        Oceania             Wallis and Futuna 2020-12-11      27750.0
# 5  South America                     Venezuela 2020-12-11    5876464.0
#
#    total_deaths  gdp_per_capita  human_development_index  month
# 0       20314.0       26382.287                    0.797     12
# 1      130519.0      116935.600                    0.933     12
# 2       52147.0       94277.965                    0.953     12
# 3      247220.0       54225.446                    0.926     12
# 4         907.0       44648.710                    0.939     12
# 5      166014.0       22767.037                    0.843     12

# %%
# Store the result in a new dataframe named 'df_groupby'.
df_groupby = df.groupby("continent").max().reset_index()

# %%
df_groupby
# Out:
#        continent                      location       date  total_cases  \
# 0         Africa                      Zimbabwe 2020-12-11     752269.0
# 1           Asia                         Yemen 2020-12-11    8874290.0
# 2         Europe                       Vatican 2020-12-11    1991233.0
# 3  North America  United States Virgin Islands 2020-12-11   11205486.0
# 4        Oceania             Wallis and Futuna 2020-12-11      27750.0
# 5  South America                     Venezuela 2020-12-11    5876464.0
#
#    total_deaths  gdp_per_capita  human_development_index  month
# 0       20314.0       26382.287                    0.797     12
# 1      130519.0      116935.600                    0.933     12
# 2       52147.0       94277.965                    0.953     12
# 3      247220.0       54225.446                    0.926     12
# 4         907.0       44648.710                    0.939     12
# 5      166014.0       22767.037                    0.843     12

# %% [markdown]
# ## Feature Engineering :

# %%
#  Create a new feature 'total_deaths_to_total_cases' by ratio of 'total_deaths' column to 'total_cases'
df_groupby["total_deaths_to_total_cases"] = df_groupby["total_deaths"]/df_groupby["total_cases"]
df_groupby
# Out:
#        continent                      location       date  total_cases  \
# 0         Africa                      Zimbabwe 2020-12-11     752269.0
# 1           Asia                         Yemen 2020-12-11    8874290.0
# 2         Europe                       Vatican 2020-12-11    1991233.0
# 3  North America  United States Virgin Islands 2020-12-11   11205486.0
# 4        Oceania             Wallis and Futuna 2020-12-11      27750.0
# 5  South America                     Venezuela 2020-12-11    5876464.0
#
#    total_deaths  gdp_per_capita  human_development_index  month  \
# 0       20314.0       26382.287                    0.797     12
# 1      130519.0      116935.600                    0.933     12
# 2       52147.0       94277.965                    0.953     12
# 3      247220.0       54225.446                    0.926     12
# 4         907.0       44648.710                    0.939     12
# 5      166014.0       22767.037                    0.843     12
#
# ...

# %% [markdown]
# ## Data Visualization :

# %%
# Perform Univariate analysis on 'gdp_per_capita' column by plotting histogram using seaborn dist plot.
plt.figure(figsize=(6,4))
sns.distplot(df["gdp_per_capita"])
plt.title("Distribution of GDP per Capita")
plt.xlabel("GDP per Capita")
plt.ylabel("Density")
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_3676\542377421.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["gdp_per_capita"])
# Text(0, 0.5, 'Density')

# %%
# Plot a scatter plot of 'total_cases' & 'gdp_per_capita'
plt.figure(figsize=(6,6))
sns.jointplot(data=df_groupby, x="total_cases",y="gdp_per_capita")
plt.xlabel("Total Cases")
plt.ylabel("GDP per Capita")
plt.show()

# %%
# Plot Pairplot on df_groupby dataset.
sns.pairplot(df_groupby)

# %%
# Plot a bar plot of 'continent' column with 'total_cases' .
plt.figure(figsize=(6,6))
sns.catplot(data=df_groupby, x="continent", y="total_cases", kind='bar')
plt.xticks(rotation=45, ha='right')
plt.title("Total COVID-19 Cases by Continent")
plt.xlabel('Continent')
plt.ylabel('Total COVID-19 Cases')
plt.show()

# %% [markdown]
# ## Save the df_groupby dataframe in your local drive using pandas.to_csv function

# %%
df_groupby.to_csv('df_groupby.csv', index=False)
